# %% [markdown]
# <a href="https://colab.research.google.com/github/ykhier/Cloud_Course/blob/main/Lab9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gemini: Creating a prompt
# This rich example shows how you can create and configure complex prompts for Gemini. It assumes that you've already created an API key at https://aistudio.google.com/app/apikey and added it to your Colab secrets as GOOGLE_API_KEY (see the "Connecting to Gemini" snippet).

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyCDC2AT2O1iUx7B_GQPZLZH5yIuVPI7LRE")
model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content("write questions for journalism interview on sports in USA")
print(response.text)
# Out:
# Okay, these questions are designed for a wide range of interviewees in the sports world in the USA – from athletes and coaches to executives, journalists, and fans. They aim to elicit thoughtful, insightful answers beyond simple yes/no responses.
#
# I've categorized them for easier navigation during an interview.
#
# ---
#
# **General / Opening Questions**
#
# 1.  How would you describe the current pulse of sports in America right now? What's the biggest story you're following?
# 2.  In your opinion, what truly defines American sports culture compared to other parts of the world?
# 3.  What's one aspect of American sports that you believe is often misunderstood or overlooked by the general public?
#
# **Professional Sports**
#
# 4.  Which professional league (NFL, NBA, MLB, NHL, MLS, WNBA, NWSL, etc.) do you think is in the strongest position currently, and why?
# 5.  Conversely, which league faces the most significant challenges, and what are those challenges?
# 6.  How has the business model of professional sports leagues evolved in recent years, especially concerning media rights and fan engagement?
# 7.  What's your take on player empowerment and athlete activism in professional sports today? How has it changed the dynamic between players, teams, and leagues?
# 8.  With the rise of international talent, how do you see the global influence shaping American professional sports?
#
# **Collegiate Sports (NCAA)**
#
# 9.  The NCAA has undergone immense changes recently, particularly with Name, Image, and Likeness (NIL) and the transfer portal. What's been the most significant impact of these changes?
# 10. Do you believe the current model for collegiate athletics is sustainable in the long term? Why or why not?
# 11. How has the focus shifted, if at all, between academics and athletics in major college programs?
# 12. What role do you see conferences playing in the future of college sports, especially with ongoing realignments?
# 13. Is the concept of "amateurism" still relevant in college sports, or is it a relic of the past?
#
# **Youth Sports**
#
# 14. What are your observations on the state of youth sports in America today? Are we doing enough to foster healthy competition and development?
# 15. There's concern about the cost and professionalization of youth sports. How is this impacting participation and accessibility?
# 16. Do you see a trend towards early specialization in sports, and what are the potential benefits and drawbacks of that approach?
#
# **Women's Sports**
#
# 17. Women's sports in the U.S. have seen unprecedented growth and visibility recently. What do you attribute this to, and where do you see its trajectory heading?
# 18. What are the key remaining barriers to achieving full equity and parity for women's sports in terms of pay, media coverage, and investment?
# 19. Which women's league or sport do you believe has the most potential for growth in the next 5-10 years?
#
# **Technology, Media & Fan Experience**
#
# 20. How has technology, from data analytics to streaming services, fundamentally changed how we consume and understand sports?
# 21. What impact has the legalization of sports gambling had on fan engagement and the integrity of the game?
# 22. How are teams and leagues adapting the in-person stadium experience to compete with high-quality home viewing options?
# 23. What role does social media play in building fan communities and influencing sports narratives today?
#
# **Social & Cultural Impact**
#
# 24. How do sports in America reflect or influence broader societal trends and issues, such as politics, race, and identity?
# 25. In what ways do sports continue to unite communities and the nation, even in polarized times?
# 26. What responsibilities do athletes, teams, and leagues have beyond the field of play, especially regarding social issues?
#
# **Challenges & Controversies**
#
# 27. Player safety, especially concerning concussions and long-term health, remains a critical issue. What more needs to be done to protect athletes at all levels?
# 28. What are your concerns about the increasing commercialization of sports, and does it risk alienating the average fan?
# 29. How are American sports grappling with issues of diversity, equity, and inclusion, particularly in leadership and coaching roles?
#
# **The Future of Sports**
#
# 30. Looking ahead 5-10 years, what do you predict will be the most significant change or trend in American sports?
# 31. Are there any emerging sports or alternative forms of competition that you see gaining significant traction in the U.S.?
# 32. What excites you most about the future of sports in America, and what worries you most?
#
# ---
#
# **Interviewee-Specific / Closing (if applicable to their role)**
#
# 33. (If a player/coach) What's the biggest misconception people have about being a professional/collegiate athlete/coach in the U.S.?
# 34. (If an executive) What's the most challenging aspect of managing a sports organization in today's landscape?
# 35. (If a journalist) What's the biggest challenge facing sports journalism right now, and how has your approach to storytelling changed?
# 36. Is there anything else you think is crucial for people to understand about sports in the USA that we haven't covered?
#
# ---
#
# **Tips for the Interviewer:**
#
# *   **Listen actively:** Your best follow-up questions will come from what the interviewee says.
# *   **Be prepared:** Research your interviewee and the specific topics you want to cover.
# *   **Open-ended is key:** Avoid "yes/no" questions. Start with "How," "What," "Why," "Tell me about..."
# *   **Don't be afraid to go off-script:** If the conversation takes an interesting turn, follow it.
# *   **Vary your questions:** Mix broad questions with specific ones.
# *   **Be respectful of their time:** Keep track of how long the interview has been going.

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

#Returns a Markdown object that can be used to render markdown from the modified text.
def  to_markdown(text):
  text = text.replace('•', ' *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))
model = genai.GenerativeModel('gemini-2.5-flash')

# Display formatted Markdown response
response = model.generate_content("count number of chracters the following text: Collage emerged in 13th-century Europe, evolving through medieval & Victorian uses. Picasso and Braque's 1912 work popularized it, but earlier examples exist.")
to_markdown(response.text)
# Out:
# > The text has **158** characters.
